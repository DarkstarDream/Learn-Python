# %% [markdown]
# ## Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')

# %%
x = [x for x in np.arange(-1000, 1100, .5)]
x2 = [i**2 for i in x]
x3 = [i**3 for i in x]
x4 = [i**4 for i in x]
x5 = [i**5 for i in x]

# %%
plt.figure(figsize=(14,10))
# plt.plot(x, x2, color='red', label='x2')
plt.plot(x, x2, color='purple', label='x5')
# plt.plot(x, log2, color='green', label='log2')
plt.legend()
plt.show()

# %%
a = np.random.randn(3,4)
b = np.random.randn(4,1)

for i in range(3):
     for j in range(4):
        c[i][j] = a[i][j] + b[j]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-0ce79f1d28bb> in <module>
#       1 a = np.random.randn(3,4)
#       2 b = np.random.randn(4,1)
# ----> 3 c = np.array()
#       4 for i in range(3):
#       5      for j in range(4):
#
# TypeError: array() missing required argument 'object' (pos 1)

# %%
a = np.random.randn(4,3,2)

# %%
np.prod(a.shape)
# Out:
# 24

# %% [markdown]
# $z = w^{T}x + b$

# %%
assert type(a) == 'numpy.ndarray'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-63-1a1930237d13> in <module>
# ----> 1 assert type(a) == 'numpy.ndarray'
#
# AssertionError:

# %%
type(a)
# Out:
# numpy.ndarray
